# %%
import youtube_dl
import pprint

# test video
video_url='https://vimeo.com/238089990' # highres = 25MB
video_url='https://vimeo.com/238190750' # lowres = 5MB

ydl_options = {
    'outtmpl': '%(id)s.%(ext)s',  # use the video id for filename
    'writethumbnail': False,
    'no_warnings': True,
    'continuedl': False,
    'restrictfilenames':True,
    'quiet': False,
    'format': "bestvideo[height<=720][ext=mp4]+bestaudio[ext=m4a]/best[height<=720][ext=mp4]", # Note the format specification is important so we get mp4 and not taller than 720
}



with youtube_dl.YoutubeDL(ydl_options) as ydl:
    try:
        ydl.add_default_info_extractors()
        vinfo = ydl.extract_info(video_url, download=True)
    except (youtube_dl.utils.DownloadError,youtube_dl.utils.ContentTooShortError,youtube_dl.utils.ExtractorError) as e:
        print('error_occured')


pp = pprint.PrettyPrinter()
del vinfo['formats']  # to keep from printing 100+ lines
del vinfo['requested_formats']  # to keep from printing 100+ lines
pp.pprint(vinfo)
# Out:
# [vimeo] 238190750: Downloading webpage
# [vimeo] 238190750: Extracting information
# [vimeo] 238190750: Downloading webpage
# [vimeo] 238190750: Downloading JSON metadata
# [vimeo] 238190750: Downloading akfire_interconnect_quic m3u8 information
# [vimeo] 238190750: Downloading fastly_skyfire m3u8 information
# [vimeo] 238190750: Downloading akfire_interconnect_quic MPD information
# [vimeo] 238190750: Downloading akfire_interconnect_quic MPD information
# [vimeo] 238190750: Downloading fastly_skyfire MPD information
# [vimeo] 238190750: Downloading fastly_skyfire MPD information
# [dashsegments] Total fragments: 15
# [download] Destination: 238190750.fdash-fastly_skyfire_sep-video-850474370.mp4
# [download] 100% of 3.38MiB in 00:05.53MiB/s ETA 00:000162
# [dashsegments] Total fragments: 15
# [download] Destination: 238190750.fdash-fastly_skyfire_sep-audio-850474370.m4a
# [download] 100% of 1.14MiB in 00:02.02MiB/s ETA 00:0002257
# [ffmpeg] Merging formats into "238190750.mp4"
# Deleting original file 238190750.fdash-fastly_skyfire_sep-video-850474370.mp4 (pass -k to keep)
# Deleting original file 238190750.fdash-fastly_skyfire_sep-audio-850474370.m4a (pass -k to keep)
# {'abr': None,
#  'acodec': 'mp4a.40.2',
#  'comment_count': None,
#  'description': 'chocmoose.com\n'
#                 'Ein animiertes Video für die 12,7 Millionen Mitglieder der '
#                 'United Methodist Church, die eine Hoffnungstradition auf die '
#                 '65 Millionen Flüchtlinge und Vertriebenen der Welt anheizt, '
#                 'die versuchen, Krieg, Gewalt und Verfolgung zu entgehen.\n'
#                 'An animated video created for the 12.7 million-member United '
#                 'Methodist Church that fuels a tradition of hope for the '
#                 'world’s 65 million refugees and displaced persons trying to '
#                 'escape war, violence and persecution.',
#  'display_id': '238190750',
#  'duration': 80,
#  'ext': 'mp4',
#  'extractor': 'vimeo',
#  'extractor_key': 'Vimeo',
#  'format': 'dash-fastly_skyfire_sep-video-850474370 - 352x200 (DASH '
#            'video)+dash-fastly_skyfire_sep-audio-850474370 - audio only (DASH '
#            'audio)',
#  'format_id': 'dash-fastly_skyfire_sep-video-850474370+dash-fastly_skyfire_sep-audio-850474370',
#  'fps': 15,
#  'height': 200,
#  'id': '238190750',
#  'license': 'by-nc-nd',
#  'like_count': None,
#  'playlist': None,
#  'playlist_index': None,
#  'requested_subtitles': None,
#  'resolution': None,
#  'stretched_ratio': None,
#  'subtitles': {},
#  'thumbnail': 'https://i.vimeocdn.com/video/660820029_960.jpg',
#  'thumbnails': [{'id': '0',
#                  'url': 'https://i.vimeocdn.com/video/660820029_960.jpg'}],
#  'timestamp': 1507975234,
#  'title': 'German - The Migrant',
#  'upload_date': '20171014',
#  'uploader': 'Chocolate Moose / Firdaus Kharas',
#  'uploader_id': 'firdauskharas',
#  'uploader_url': 'https://vimeo.com/firdauskharas',
#  'vbr': None,
#  'vcodec': 'avc1.64001E',
#  'view_count': None,
#  'webpage_url': 'https://vimeo.com/238190750',
#  'webpage_url_basename': '238190750',
#  'width': 352}
