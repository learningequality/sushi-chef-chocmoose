# %%
import pickle
import os
import pprint

if not os.path.exists('chocmoose_info.pickle'):
    print("error, missing chocmoose_info.pickle, please download and unzip in current dir.")

    
with open('chocmoose_info.pickle', 'rb') as handle:
    info = pickle.load(handle)

# %%
# LOOK AROUND
########################################################################
print(info.keys())

# non-entries keys
keys = ['extractor', 'extractor_key', 'title', '_type', 'webpage_url', 'id', 'webpage_url_basename']
for key in keys:
    print(key, ':', info[key])
    
# number of entries
print("\n\nlen(info['entries'] = ", len(info['entries']) )

# sample entry
pp = pprint.PrettyPrinter()
vinfo=info['entries'][5].copy()
del vinfo['formats']  # to keep from printing 100+ lines
del vinfo['requested_formats']  # to keep from printing 100+ lines
pp.pprint(vinfo)
# Out:
# dict_keys(['entries', 'extractor', 'extractor_key', 'title', '_type', 'webpage_url', 'id', 'webpage_url_basename'])
# extractor : vimeo:user
# extractor_key : VimeoUser
# title : Chocolate Moose / Firdaus Kharas
# _type : playlist
# webpage_url : https://vimeo.com/firdauskharas
# id : firdauskharas
# webpage_url_basename : firdauskharas
#
#
# len(info['entries'] =  3623
# {'abr': None,
#  'acodec': 'mp4a.40.2',
#  'comment_count': None,
#  'description': 'This is "German - The Migrant" by Chocolate Moose / Firdaus '
#                 'Kharas on Vimeo, the home for high quality videos and the '
#                 'people who love them.',
#  'display_id': '238089990',
#  'duration': 80,
#  'ext': 'mp4',
#  'extractor': 'vimeo',
#  'extractor_key': 'Vimeo',
#  'format': 'dash-fastly_skyfire_sep-video-850001630 - 1920x1080 (DASH '
#            'video)+dash-fastly_skyfire_sep-audio-850001645 - audio only (DASH '
#            'audio)',
# ...

# %%
for vid in info['entries']:
    print(vid['webpage_url'], vid['title'])
# Out:
# https://vimeo.com/238190857 The Migrant
# https://vimeo.com/238190750 German - The Migrant
# https://vimeo.com/238190678 French - The Migrant
# https://vimeo.com/238190643 Coming Together
# https://vimeo.com/238106308 Show You Care, Wear A Pair
# https://vimeo.com/238089990 German - The Migrant
# https://vimeo.com/238089803 French - The Migrant
# https://vimeo.com/238089595 The Migrant
# https://vimeo.com/237591649 Show You Care, Wear A Pair
# https://vimeo.com/235153759 Congo Tshiluba Mix 1 hi rez
# https://vimeo.com/235153667 Rape Victims - Luganda
# https://vimeo.com/235153568 Rape Victims - Mashi
# https://vimeo.com/235153494 Rape Victims - Lingala
# https://vimeo.com/234933905 UNICEF cyber-security - English
# https://vimeo.com/234933854 UNICEF cyber-security video - Francais
# https://vimeo.com/234736230 Congo Tshiluba Mix 1 hi rez
# https://vimeo.com/234735858 Rape Victims - Mashi
# https://vimeo.com/234735489 Rape Victims - Luganda
# ...

# %%
# EXPLORE VIDEOS with IDENTICAL TITLES

sp_ids = [
"https://vimeo.com/218249168",   # lowres. 3x same video in Spanish
"https://vimeo.com/217605814",   # highres (best to choose one of the highres)
"https://vimeo.com/217605806",   # highres 

"https://vimeo.com/214431304", # 3x same video in FR, 
"https://vimeo.com/214431300", # with slightlitydifferent dubbing
"https://vimeo.com/214431289", # 

"https://vimeo.com/238190750", # lowres
"https://vimeo.com/238089990", # highres
]


for vid in info['entries']:
    if vid['webpage_url'] in sp_ids:
        print(vid['webpage_url'], vid['title'], vid['timestamp'])
        print('formats:')
        formats = vid['formats']
        for f in formats:
            if 'http' in f['format_id']:
                print('  -', f['format'])
# Out:
# https://vimeo.com/238190750 German - The Migrant 1507975234
# formats:
#   - http-360p - 352x200
#   - http-540p - 352x200
# https://vimeo.com/238089990 German - The Migrant 1507896071
# formats:
#   - http-360p - 640x360
#   - http-540p - 960x540
#   - http-720p - 1280x720
#   - http-1080p - 1920x1080
# https://vimeo.com/218249168 Spanish, español- Asbestos (Amianto) 3GP 1495237689
# formats:
#   - http-360p - 640x360
#   - http-540p - 960x540
# https://vimeo.com/217605814 Spanish, español- Asbestos (Amianto) 1494887985
# formats:
#   - http-360p - 640x360
#   - http-540p - 960x540
#   - http-720p - 1280x720
#   - http-1080p - 1920x1080
# https://vimeo.com/217605806 Spanish, español- Asbestos (Amianto) 1494887978
# formats:
#   - http-360p - 640x360
#   - http-540p - 960x540
#   - http-720p - 1280x720
#   - http-1080p - 1920x1080
# https://vimeo.com/214431304 French, français- Rape Victims, Victimes du viol 1492982619
# formats:
#   - http-360p - 640x360
#   - http-540p - 960x540
# ...
